# %%
import numpy as np
from matplotlib import pyplot as plt
def sampling_lines_alt(ax, duration):

    x = np.linspace(0,130,70)
    y = x / duration
    ax.plot(x,y, label=f'∆ = {duration:.2f}')

    ax.set_xticks(np.arange(8, 100, 8.0))
    ax.set_yticks(np.arange(2, 25, 1.0))
    ax.set_xlabel('T')
    ax.set_ylabel('24 / τ')
    ax.grid(True)

    ax.legend()
    return
    ax.scatter([16, 32, 64], [6, 12, 24])
    x = np.linspace(0,130,70)
    y = x / (64 / 24)
    ax.plot(x,y, label=f'{(64 / 24):.2f}')

    ax.scatter([16, 32, 48, 96], [4, 8, 12, 24])
    x = np.linspace(0,130,70)
    y = x / (96 / 24)
    ax.plot(x,y, label=f'{(96 / 24):.2f}')

    ax.scatter([16, 32, 48, 64], [3, 6, 9, 12])
    x = np.linspace(0,130,70)
    y = x / (128 / 24)
    ax.plot(x,y, label=f'{(128 / 24):.2f}')

    ax.scatter([16, 32, 48, 64, 80], [2, 5, 7, 10, 12])
    x = np.linspace(0,130,70)
    y = x / (160 / 24)
    ax.plot(x,y, label=f'{(160 / 24):.2f}')

    return ax

# %%
ax = sampling_lines_alt()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-5473a929fed9> in <module>
# ----> 1 ax = sampling_lines_alt()
#       2
#       3
#
# TypeError: sampling_lines_alt() missing 2 required positional arguments: 'ax' and 'duration'

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax.set_title('R2+1D')

ax.scatter([64, 56, 48, 40, 32, 24, 16], [24, 21, 18, 15, 12, 9, 6])
sampling_lines_alt(ax, 64 / 24)
ax.arrow(32, 24, 32, 0, head_width=0.3, head_length=1, fc='k', ec='k', length_includes_head=True)
ax.annotate(60.6, (64, 24.1))
ax.arrow(32, 24, 16, -6, head_width=0.3, head_length=1, fc='k', ec='k', length_includes_head=True)
ax.annotate('?', (32, 12.1))
ax.arrow(32, 24, 0, -12, head_width=0.3, head_length=1, fc='k', ec='k', length_includes_head=True)
ax.annotate(59.6, (32, 12.1))

ax.scatter([96, 80, 72, 64, 56, 48, 40, 32, 24], [24, 20, 18, 16, 14, 12, 10, 8, 6])
sampling_lines_alt(ax, 96 / 24)
ax.arrow(32, 12, 16, 0, head_width=0.3, head_length=1, fc='k', ec='k', length_includes_head=True)
ax.annotate(61.4, (48, 12.1))

ax.scatter([96, 80, 64, 48, 32], [18, 15, 12, 9, 6])
sampling_lines_alt(ax, 128 / 24)

ax.scatter([32], [24])
sampling_lines_alt(ax, 32 / 24)
ax.annotate(58.2, (28, 24))

sampling_lines_alt(ax, 48 / 24)


fig.savefig('/Users/simonnarendorf/Documents/Projects/soccer-action-classification/Thesis/img/07_grid_r2plus1d.eps', format='eps')

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax.set_title('SlowFast')
ax.scatter([32], [12])
sampling_lines_alt(ax, 64 / 24)
ax.annotate(62.3, (32, 12))


ax.scatter([96, 88, 80, 72, 64, 56, 48, 40, 32, 24], [24, 22, 20, 18, 16, 14, 12, 10, 8, 6])
sampling_lines_alt(ax, 96 / 24)

ax.arrow(32, 12, 16, 0, head_width=0.3, head_length=1, fc='k', ec='k', length_includes_head=True)
ax.annotate(59.7, (32, 8))
ax.arrow(32, 12, 0, -4, head_width=0.3, head_length=1, fc='k', ec='k', length_includes_head=True)
ax.annotate(62.8, (16, 0))
ax.arrow(32, 12, 8, -2, head_width=0.3, head_length=1, fc='k', ec='k', length_includes_head=True)
ax.annotate('?', (40, 10))

fig.savefig('/Users/simonnarendorf/Documents/Projects/soccer-action-classification/Thesis/img/07_grid_slowfast.eps', format='eps')

# %%
fig, ax = plt.subplots(figsize=(5,5))


ax.set_title('Grid Search')

# 3 sec
ax.scatter([24, 32, 40, 48], [8, 10, 13, 16])
sampling_lines_alt(ax, 72 / 24)
#ax.annotate(64.1, (32, 12))

# 4.0 sec
ax.scatter([24, 32, 40, 48, 56, 64], [6, 8, 10, 12, 14, 16])
sampling_lines_alt(ax, 96 / 24)

# 5 sec
ax.scatter([24, 32, 40, 48, 56, 64], [5, 7, 8, 10, 11, 13])
sampling_lines_alt(ax, 120 / 24)

# 6 sec
ax.scatter([24, 32, 40, 48, 56, 64], [4, 6, 7, 8, 10, 11])
sampling_lines_alt(ax, 144 / 24)

# 7 sec
#ax.scatter([32, 40, 48, 56, 64], [5, 6, 7, 8, 10])
#sampling_lines_alt(ax, 168 / 24)

#baseline
ax.scatter([32], [12])

ax.set_xlim(16,72)
ax.set_ylim(3,17)
ax.set_xticks(np.arange(16, 72, 8.0))


fig.savefig('/Users/simonnarendorf/Documents/Projects/soccer-action-classification/Thesis/img/07_grid_csn.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ax = plt.subplots(figsize=(5,5))

#ax.plot([24,32,40,48,56,64], [60,64.7,65.1,68.3,68.2,60], label='balanced accuracy')
ax.plot([24,32,40,48,56,64], [30.4,30.4,31.2,38.3,38.1,37.8], label='recall')
ax.plot([24,32,40,48,56,64], [39.0,37.0,39.9,35.3,36.4,36.0], label='precision')
ax.legend()
ax.set_xlabel('T')
ax.set_xticks(np.arange(24, 70, 8.0))
ax.set_title('∆ = 4.0')
# Out:
# Text(0.5, 1.0, '∆ = 4.0')

# %%
import pandas as pd
import plotly.express as px
df = pd.DataFrame(dict(
    num_frames=[
        24, 24, 24, 24,
        32, 32, 32, 32, 32,
        40, 40, 40, 40,
        48, 48, 48, 48, 48,
        56, 56, 56,
        64, 64, 64
    ],
    fps=[
        4,  5,  6,  8,
        6,  7,  8, 10, 12,
        7,  8, 10, 13,
        8,  9, 10, 12, 16,
        10,11, 14,
        11,12,16,
    ],
    duration=[
        6.0, 4.8, 4.0, 3.0,
        5.3, 4.6, 4.0, 3.2, 2.7,
        5.7, 5.0, 4.0, 3.1,
        6.0, 5.3, 4.8, 4.0, 3.0,
        5.6, 5.1, 4.0,
        5.8, 5.3, 4.0,
    ],
    balanced_accuracy=[
        64.1, 64.7, 64.7, 64.3,
        64.9, 65.6, 64.7, 64.9, 64.1,
        66.0, 65.3, 65.1, 64.4,
        68.2, 67.9, 68.3, 68.3, 66.9,
        67.4, 67.8, 68.2,
        67.8, 66.1, 68.1,
    ],
    recall=[
        29.3, 30.4, 30.4, 29.5,
        30.8, 32.3, 30.4, 30.8, 29.3,
        32.9, 31.5, 31.2, 29.7,
        38.1, 37.5, 38.0, 38.3, 35.4,
        36.3, 37.2, 38.1,
        37.7, 33.8, 37.8,
    ],
    precision=[
        38.8, 38.9, 39.0, 39.1,
        38.9, 40.6, 37.0, 40.0, 36.9,
        41.1, 40.5, 39.9, 40.6,
        36.2, 36.1, 37.5, 35.3, 35.4,
        36.4, 36.3, 36.4,
        29.7, 33.3, 36.0,
    ]
))

# %%
metric = 'precision'
#metric = 'balanced_accuracy'
fig = px.parallel_coordinates(df[['num_frames', 'fps', 'duration', metric]], color=metric, labels={
    "duration": "∆",
    "num_frames": "T",
    "fps": "24 / τ",
    "recall": "Recall",
    "precision": "Precision"
}, color_continuous_scale=px.colors.diverging.Tealrose, )
fig.show()
fig.write_image("/Users/simonnarendorf/Documents/Projects/soccer-action-classification/Thesis/img/07_par_cor_prec.eps", engine="kaleido", scale=5.0)
# Out:
# <div>                            <div id="2811fe7a-1c92-4f3d-bfdb-ba59554ed92a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2811fe7a-1c92-4f3d-bfdb-ba59554ed92a")) {                    Plotly.newPlot(                        "2811fe7a-1c92-4f3d-bfdb-ba59554ed92a",                        [{"dimensions": [{"label": "T", "values": [24, 24, 24, 24, 32, 32, 32, 32, 32, 40, 40, 40, 40, 48, 48, 48, 48, 48, 56, 56, 56, 64, 64, 64]}, {"label": "24 / \u03c4", "values": [4, 5, 6, 8, 6, 7, 8, 10, 12, 7, 8, 10, 13, 8, 9, 10, 12, 16, 10, 11, 14, 11, 12, 16]}, {"label": "\u2206", "values": [6.0, 4.8, 4.0, 3.0, 5.3, 4.6, 4.0, 3.2, 2.7, 5.7, 5.0, 4.0, 3.1, 6.0, 5.3, 4.8, 4.0, 3.0, 5.6, 5.1, 4.0, 5.8, 5.3, 4.0]}, {"label": "Precision", "values": [38.8, 38.9, 39.0, 39.1, 38.9, 40.6, 37.0, 40.0, 36.9, 41.1, 40.5, 39.9, 40.6, 36.2, 36.1, 37.5, 35.3, 35.4, 36.4, 36.3, 36.4, 29.7, 33.3, 36.0]}], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "line": {"color": [38.8, 38.9, 39.0, 39.1, 38.9, 40.6, 37.0, 40.0, 36.9, 41.1, 40.5, 39.9, 40.6, 36.2, 36.1, 37.5, 35.3, 35.4, 36.4, 36.3, 36.4, 29.7, 33.3, 36.0], "coloraxis": "coloraxis"}, "name": "", "type": "parcoords"}],                        {"coloraxis": {"colorbar": {"title": {"text": "Precision"}}, "colorscale": [[0.0, "rgb(0, 147, 146)"], [0.16666666666666666, "rgb(114, 170, 161)"], [0.3333333333333333, "rgb(177, 199, 179)"], [0.5, "rgb(241, 234, 200)"], [0.6666666666666666, "rgb(229, 185, 173)"], [0.8333333333333334, "rgb(217, 137, 148)"], [1.0, "rgb(208, 88, 126)"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, ...

# %%
metric = 'recall'
#metric = 'balanced_accuracy'
fig = px.parallel_coordinates(df[['num_frames', 'fps', 'duration', metric]], color=metric, labels={
    "duration": "∆",
    "num_frames": "T",
    "fps": "24 / τ",
    "recall": "Recall",
    "precision": "Precision"
}, color_continuous_scale=px.colors.diverging.Tealrose, )
fig.show()
fig.write_image("/Users/simonnarendorf/Documents/Projects/soccer-action-classification/Thesis/img/07_par_cor_rec.eps", engine="kaleido", scale=5.0)
# Out:
# <div>                            <div id="e8b6126c-aa29-445b-85e9-0bc2c90c3ad7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8b6126c-aa29-445b-85e9-0bc2c90c3ad7")) {                    Plotly.newPlot(                        "e8b6126c-aa29-445b-85e9-0bc2c90c3ad7",                        [{"dimensions": [{"label": "T", "values": [24, 24, 24, 24, 32, 32, 32, 32, 32, 40, 40, 40, 40, 48, 48, 48, 48, 48, 56, 56, 56, 64, 64, 64]}, {"label": "24 / \u03c4", "values": [4, 5, 6, 8, 6, 7, 8, 10, 12, 7, 8, 10, 13, 8, 9, 10, 12, 16, 10, 11, 14, 11, 12, 16]}, {"label": "\u2206", "values": [6.0, 4.8, 4.0, 3.0, 5.3, 4.6, 4.0, 3.2, 2.7, 5.7, 5.0, 4.0, 3.1, 6.0, 5.3, 4.8, 4.0, 3.0, 5.6, 5.1, 4.0, 5.8, 5.3, 4.0]}, {"label": "Recall", "values": [29.3, 30.4, 30.4, 29.5, 30.8, 32.3, 30.4, 30.8, 29.3, 32.9, 31.5, 31.2, 29.7, 38.1, 37.5, 38.0, 38.3, 35.4, 36.3, 37.2, 38.1, 37.7, 33.8, 37.8]}], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "line": {"color": [29.3, 30.4, 30.4, 29.5, 30.8, 32.3, 30.4, 30.8, 29.3, 32.9, 31.5, 31.2, 29.7, 38.1, 37.5, 38.0, 38.3, 35.4, 36.3, 37.2, 38.1, 37.7, 33.8, 37.8], "coloraxis": "coloraxis"}, "name": "", "type": "parcoords"}],                        {"coloraxis": {"colorbar": {"title": {"text": "Recall"}}, "colorscale": [[0.0, "rgb(0, 147, 146)"], [0.16666666666666666, "rgb(114, 170, 161)"], [0.3333333333333333, "rgb(177, 199, 179)"], [0.5, "rgb(241, 234, 200)"], [0.6666666666666666, "rgb(229, 185, 173)"], [0.8333333333333334, "rgb(217, 137, 148)"], [1.0, "rgb(208, 88, 126)"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#720 ...

# %%
metric = 'balanced_accuracy'
fig = px.parallel_coordinates(df[['num_frames', 'fps', 'duration', metric]], color=metric, labels={
    "duration": "∆",
    "num_frames": "T",
    "fps": "24 / τ",
    "balanced_accuracy": "Balanced Accuracy",
    "recall": "Recall",
    "precision": "Precision"
}, color_continuous_scale=px.colors.diverging.Tealrose, )
fig.show()
fig.write_image("/Users/simonnarendorf/Documents/Projects/soccer-action-classification/Thesis/img/07_par_cor_ba.eps", engine="kaleido", scale=5.0)
# Out:
# <div>                            <div id="a0ea61d4-935f-41eb-b9ae-41414e134fd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0ea61d4-935f-41eb-b9ae-41414e134fd6")) {                    Plotly.newPlot(                        "a0ea61d4-935f-41eb-b9ae-41414e134fd6",                        [{"dimensions": [{"label": "T", "values": [24, 24, 24, 24, 32, 32, 32, 32, 32, 40, 40, 40, 40, 48, 48, 48, 48, 48, 56, 56, 56, 64, 64]}, {"label": "24 / \u03c4", "values": [4, 5, 6, 8, 6, 7, 8, 10, 12, 7, 8, 10, 13, 8, 9, 10, 12, 16, 10, 11, 14, 12, 16]}, {"label": "\u2206", "values": [6.0, 4.8, 4.0, 3.0, 5.3, 4.6, 4.0, 3.2, 2.7, 5.7, 5.0, 4.0, 3.1, 6.0, 5.3, 4.8, 4.0, 3.0, 5.6, 5.1, 4.0, 5.3, 4.0]}, {"label": "Balanced Accuracy", "values": [64.1, 64.7, 64.7, 64.3, 64.9, 65.6, 64.7, 64.9, 64.1, 66.0, 65.3, 65.1, 64.4, 68.2, 67.9, 68.3, 68.3, 66.9, 67.4, 67.8, 68.2, 66.1, 68.1]}], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "line": {"color": [64.1, 64.7, 64.7, 64.3, 64.9, 65.6, 64.7, 64.9, 64.1, 66.0, 65.3, 65.1, 64.4, 68.2, 67.9, 68.3, 68.3, 66.9, 67.4, 67.8, 68.2, 66.1, 68.1], "coloraxis": "coloraxis"}, "name": "", "type": "parcoords"}],                        {"coloraxis": {"colorbar": {"title": {"text": "Balanced Accuracy"}}, "colorscale": [[0.0, "rgb(0, 147, 146)"], [0.16666666666666666, "rgb(114, 170, 161)"], [0.3333333333333333, "rgb(177, 199, 179)"], [0.5, "rgb(241, 234, 200)"], [0.6666666666666666, "rgb(229, 185, 173)"], [0.8333333333333334, "rgb(217, 137, 148)"], [1.0, "rgb(208, 88, 126)"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8 ...

# %%
from pandas.plotting import andrews_curves
from pandas.plotting import parallel_coordinates
from pandas.plotting import radviz
import numpy as np
#andrews_curves(df, "recall")
#df.recall = df.recall * 100
#df.plot.hexbin(x="num_frames", y="fps", gridsize=5);
parallel_coordinates(df, "precision", cols=['duration', 'num_frames', 'fps', 'precision'], sort_labels=True, colormap="gist_rainbow")
#radviz(df, "recall")
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot as plt
from matplotlib import ticker
df['recall'] = pd.cut(df['recall'], [30, 34, 38, 42, 46])

cols = ['duration', 'num_frames', 'fps']
x = [i for i, _ in enumerate(cols)]
colours = ['#2e8ad8', '#cd3785', '#c64c00', '#889a00']

# create dict of categories: colours
colours = {df['recall'].cat.categories[i]: colours[i] for i, _ in enumerate(df['recall'].cat.categories)}

# Create (X-1) sublots along x axis
fig, axes = plt.subplots(1, len(x)-1, sharey=False, figsize=(15,5))

# Get min, max and range for each column
# Normalize the data for each column
min_max_range = {}
for col in cols:
    min_max_range[col] = [df[col].min(), df[col].max(), np.ptp(df[col])]
    df[col] = np.true_divide(df[col] - df[col].min(), np.ptp(df[col]))

# Plot each row
for i, ax in enumerate(axes):
    for idx in df.index:
        mpg_category = df.loc[idx, 'recall']
        ax.plot(x, df.loc[idx, cols], colours[mpg_category])
    ax.set_xlim([x[i], x[i+1]])

# Set the tick positions and labels on y axis for each plot
# Tick positions based on normalised data
# Tick labels are based on original data
def set_ticks_for_axis(dim, ax, ticks):
    min_val, max_val, val_range = min_max_range[cols[dim]]
    step = val_range / float(ticks-1)
    tick_labels = [round(min_val + step * i, 2) for i in range(ticks)]
    norm_min = df[cols[dim]].min()
    norm_range = np.ptp(df[cols[dim]])
    norm_step = norm_range / float(ticks-1)
    ticks = [round(norm_min + norm_step * i, 2) for i in range(ticks)]
    ax.yaxis.set_ticks(ticks)
    ax.set_yticklabels(tick_labels)

for dim, ax in enumerate(axes):
    ax.xaxis.set_major_locator(ticker.FixedLocator([dim]))
    set_ticks_for_axis(dim, ax, ticks=6)
    ax.set_xticklabels([cols[dim]])


# Move the final axis' ticks to the right-hand side
ax = plt.twinx(axes[-1])
dim = len(axes)
ax.xaxis.set_major_locator(ticker.FixedLocator([x[-2], x[-1]]))
set_ticks_for_axis(dim, ax, ticks=6)
ax.set_xticklabels([cols[-2], cols[-1]])


# Remove space between subplots
plt.subplots_adjust(wspace=0)

# Add legend to plot
plt.legend(
    [plt.Line2D((0,1),(0,0), color=colours[cat]) for cat in df['recall'].cat.categories],
    df['recall'].cat.categories,
    bbox_to_anchor=(1.2, 1), loc=2, borderaxespad=0.)

plt.title("Values of car attributes by MPG category")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-ad738afd3422> in <module>
#      24     for idx in df.index:
#      25         mpg_category = df.loc[idx, 'recall']
# ---> 26         ax.plot(x, df.loc[idx, cols], colours[mpg_category])
#      27     ax.set_xlim([x[i], x[i+1]])
#      28
#
# KeyError: nan
